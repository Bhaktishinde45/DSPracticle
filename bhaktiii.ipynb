# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\supri\OneDrive\Desktop\global_ads_performance_dataset.csv")

# %%
df.head()
# Out:
#          date    platform campaign_type    industry  country  impressions  \
# 0  2024-01-21  Google Ads        Search     Fintech      UAE        59886
# 1  2024-01-22  TikTok Ads        Search      EdTech       UK       135608
# 2  2024-06-15  TikTok Ads         Video  Healthcare      USA        92313
# 3  2024-01-02  TikTok Ads      Shopping        SaaS  Germany        83953
# 4  2024-02-22  TikTok Ads        Search  Healthcare       UK        91807
#
#    clicks     CTR   CPC  ad_spend  conversions    CPA   revenue   ROAS
# 0    2113  0.0353  1.26   2662.38          159  16.74   4803.43   1.80
# 1    5220  0.0385  1.18   6159.60          411  14.99  64126.68  10.41
# 2    5991  0.0649  0.85   5092.35          267  19.07  10489.07   2.06
# 3    5935  0.0707  1.32   7834.20          296  26.47  50505.07   6.45
# 4    4489  0.0489  1.93   8663.77          107  80.97   3369.53   0.39

# %%
df.head(10)
# Out:
#          date    platform campaign_type    industry  country  impressions  \
# 0  2024-01-21  Google Ads        Search     Fintech      UAE        59886
# 1  2024-01-22  TikTok Ads        Search      EdTech       UK       135608
# 2  2024-06-15  TikTok Ads         Video  Healthcare      USA        92313
# 3  2024-01-02  TikTok Ads      Shopping        SaaS  Germany        83953
# 4  2024-02-22  TikTok Ads        Search  Healthcare       UK        91807
# 5  2024-10-15  TikTok Ads        Search     Fintech   Canada        17666
# 6  2024-08-14    Meta Ads         Video     Fintech      USA       118252
# 7  2024-04-05  TikTok Ads        Search      EdTech      UAE        92939
# 8  2024-04-17    Meta Ads       Display      EdTech  Germany        30939
# 9  2024-11-13  Google Ads      Shopping     Fintech      USA         8748
#
#    clicks     CTR   CPC  ad_spend  conversions    CPA   revenue   ROAS
# 0    2113  0.0353  1.26   2662.38          159  16.74   4803.43   1.80
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1800 non-null   object
#  1   platform       1800 non-null   object
#  2   campaign_type  1800 non-null   object
#  3   industry       1800 non-null   object
#  4   country        1800 non-null   object
#  5   impressions    1800 non-null   int64
#  6   clicks         1800 non-null   int64
#  7   CTR            1800 non-null   float64
#  8   CPC            1800 non-null   float64
#  9   ad_spend       1800 non-null   float64
#  10  conversions    1800 non-null   int64
#  11  CPA            1800 non-null   float64
#  12  revenue        1800 non-null   float64
#  13  ROAS           1800 non-null   float64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 197.0+ KB

# %%
df.describe()
# Out:
#          impressions        clicks          CTR          CPC      ad_spend  \
# count    1800.000000   1800.000000  1800.000000  1800.000000   1800.000000
# mean   102919.018889   3962.675556     0.038427     1.572756   6171.527272
# std     55740.900690   2941.858037     0.017082     0.800872   5776.996958
# min      5059.000000     91.000000     0.008900     0.280000     58.000000
# 25%     54948.000000   1678.000000     0.025400     0.950000   1966.587500
# 50%    103653.000000   3318.000000     0.035550     1.460000   4393.860000
# 75%    150470.250000   5628.000000     0.049800     2.050000   8455.830000
# max    199650.000000  16660.000000     0.095600     3.950000  38453.320000
#
#        conversions          CPA        revenue         ROAS
# count  1800.000000  1800.000000    1800.000000  1800.000000
# mean    181.562222    46.608961   30101.850450     6.450367
# std     171.424239    41.185556   34560.032941     6.590986
# ...

# %%
df.columns
# Out:
# Index(['date', 'platform', 'campaign_type', 'industry', 'country',
#        'impressions', 'clicks', 'CTR', 'CPC', 'ad_spend', 'conversions', 'CPA',
#        'revenue', 'ROAS'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# date             0
# platform         0
# campaign_type    0
# industry         0
# country          0
# impressions      0
# clicks           0
# CTR              0
# CPC              0
# ad_spend         0
# conversions      0
# CPA              0
# revenue          0
# ROAS             0
# dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# impressions    102919.018889
# clicks           3962.675556
# CTR                 0.038427
# CPC                 1.572756
# ad_spend         6171.527272
# conversions       181.562222
# CPA                46.608961
# revenue         30101.850450
# ROAS                6.450367
# dtype: float64

# %%
df.tail()
# Out:
#             date    platform campaign_type    industry    country  \
# 1795  2024-07-11  TikTok Ads         Video  E-commerce    Germany
# 1796  2024-06-23    Meta Ads       Display      EdTech  Australia
# 1797  2024-03-01    Meta Ads         Video     Fintech  Australia
# 1798  2024-08-02  Google Ads        Search  E-commerce        USA
# 1799  2024-01-29    Meta Ads       Display      EdTech         UK
#
#       impressions  clicks     CTR   CPC  ad_spend  conversions    CPA  \
# 1795       180128   10555  0.0586  0.84   8866.20          707  12.54
# 1796       169849    5927  0.0349  0.94   5571.38          437  12.75
# 1797       122974    2939  0.0239  1.85   5437.15           91  59.75
# 1798        28553     850  0.0298  2.06   1751.00           51  34.33
# 1799        77447     906  0.0117  1.15   1041.90           29  35.93
#
#         revenue   ROAS
# 1795  200566.90  22.62
# 1796  105321.92  18.90
# 1797   26004.98   4.78
# 1798   13010.72   7.43
# 1799    8284.13   7.95

# %%
df.tail(10)
# Out:
#             date    platform campaign_type    industry    country  \
# 1790  2024-07-22    Meta Ads      Shopping  E-commerce        UAE
# 1791  2024-12-26  TikTok Ads       Display     Fintech    Germany
# 1792  2024-09-03  Google Ads        Search  E-commerce      India
# 1793  2024-10-22  Google Ads        Search     Fintech        UAE
# 1794  2024-02-03    Meta Ads       Display      EdTech  Australia
# 1795  2024-07-11  TikTok Ads         Video  E-commerce    Germany
# 1796  2024-06-23    Meta Ads       Display      EdTech  Australia
# 1797  2024-03-01    Meta Ads         Video     Fintech  Australia
# 1798  2024-08-02  Google Ads        Search  E-commerce        USA
# 1799  2024-01-29    Meta Ads       Display      EdTech         UK
#
#       impressions  clicks     CTR   CPC  ad_spend  conversions    CPA  \
# 1790       133716    1617  0.0121  0.85   1374.45           48  28.63
# 1791        43319    2534  0.0585  1.66   4206.44          111  37.90
# ...

# %%
df.shape
# Out:
# (1800, 14)

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()
